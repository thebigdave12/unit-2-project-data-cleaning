# %% [markdown]
# # Unit 2 Project - Data Cleaning

# %% [markdown]
# ## Part 1: Prepare Environment and Jupyter Notebook

# %% [markdown]
# ### Step 1: Create Virtual Environment
#
# This step should have been completed prior to opening the Jupyter Notebook. Refer to project instructions.

# %% [markdown]
# ### Step 2: Open Jupyter Notebook File
#
# Congratulations! If you're here it means you have completed Step 2.

# %% [markdown]
# ### Step 3: Load .csv Files into DataFrames

# %%
####### TO DO ########

# load house_data.csv into a dataframe using pd.read_csv()

# load house_sales.csv into a dataframe using pd.read_csv()

######################

import pandas as pd

house_data_df = pd.read_csv("house_data.csv")
house_sales_df = pd.read_csv("house_sales.csv")

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was loaded succussfully

house_data_df.head(40)
# Out:
#     Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  \
# 0            0  7129300520         3       1.00         1180    5650.0
# 1            1  6414100192         3       2.25         2570    7242.0
# 2            2  5631500400         2       1.00          770   10000.0
# 3            3  2487200875         4       3.00         1960    5000.0
# 4            4  1954400510         3       2.00         1680    8080.0
# 5            5  7237550310         4       4.50         5420  101930.0
# 6            6  1321400060         3       2.25         1715    6819.0
# 7            7  2008000270         3       1.50         1060    9711.0
# 8            8  2414600126         3       1.00         1780    7470.0
# 9            9  3793500160         3       2.50         1890    6560.0
# 10          10  1736800520         3        NaN         3560    9796.0
# 11          11  9212900260         2       1.00         1160    6000.0
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was loaded succussfully
house_sales_df.head(15)
# Out:
#     Unnamed: 0          Id             DATE          Price
# 0            0  7129300520  20141013T000000    $221,900.00
# 1            1  6414100192  20141209T000000    $538,000.00
# 2            2  5631500400  20150225T000000    $180,000.00
# 3            3  2487200875  20141209T000000    $604,000.00
# 4            4  1954400510  20150218T000000    $510,000.00
# 5            5  7237550310  20140512T000000  $1,225,000.00
# 6            6  1321400060  20140627T000000    $257,500.00
# 7            7  2008000270  20150115T000000    $291,850.00
# 8            8  2414600126  20150415T000000    $229,500.00
# 9            9  3793500160  20150312T000000    $323,000.00
# 10          10  1736800520  20150403T000000    $662,500.00
# 11          11  9212900260  20140527T000000    $468,000.00
# 12          12   114101516  20140528T000000    $310,000.00
# 13          13  6054650070  20141007T000000    $400,000.00
# 14          14  1175000570  20150312T000000    $530,000.00

# %% [markdown]
# ### Step 4: Create Data Dictionaries for Each Dataset

# %%
####### TO DO ###########

# Work in the cells below to fill in missing information in the data dictionary.

# %% [markdown]
# #### Data Dictionary - House Data
#
# **id**:
# > Description:
# > ID number assigned to house in sequential number
# >
# > Data type:
# > int64
#
# **bedrooms**:
# > Description:
# > Number of bedrooms in house
# >
# > Data type:
# > int64
#
# **bathrooms**:
# > Description:
# > Number of bathrooms in house (float bc can have a .5 bath)
# >
# > Data type:
# > float64
#
# **sqft_living**:
# > Description:
# > Total area of the inside of the house in square feet
# >
# > Data type:
# > int64
#
# **sqft_lot**:
# > Description:
# > Total area of the entire property in square feet
# >
# > Data type:
# > float64
#
# **floors**:
# > Description:
# > Number of floors in the house
# >
# > Data type:
# > float64
#
# **waterfront**:
# > Description:
# > Whether or not this home's property touches water (yes or no)
# >
# > Data type:
# > object
#
# **view**:
# > Description:
# > Text rating on how the overall view is from within the house
# >
# > Data type:
# > object
#
# **condition**:
# > Description:
# > Text rating of the quality of the house
# >
# > Data type:
# > object
#
# **grade**:
# > Description:
# > Numerical ranking on the condition of the house???
# >
# > Data type:
# > float64
#
# **sqft_above**:
# > Description:
# > Size of house in squarefeet excluding basement
# >
# > Data type:
# > float64
#
# **sqft_basement**:
# > Description:
# > Size of the basement in square feet
# >
# > Data type:
# > int64
#
# **yr_built**:
# > Description:
# > Year value in which house was built
# >
# > Data type:
# > float64
#
# **yr_renovated**:
# > Description:
# > Year value if the house has been renovated since being built
# >
# > Data type:
# > float64
#
# **zipcode**:
# > Description:
# > House location by zipcode
# >
# > Data type:
# > float64
#
# **lat**:
# > Description:
# > House location by latitude
# >
# > Data type:
# > float64
#
# **long**:
# > Description:
# > House location by longitude
# >
# > Data type:
# > float64
#
# **sqft_living15**:
# > Description:
# > Average square footage of nearest 15 neighbors homes
# >
# > Data type:
# > int64
#
# **sqft_lot15**:
# > Description:
# > Average square footage of nearest 15 neighbors lots
# >
# > Data type:
# > int6

# %% [markdown]
# #### Data Dictionary - House Sales Data
#
# **id**:
# > Description: ID number assigned to sale of a house in sequential order
# >
# > Data type: int64
#
# **date**:
# > Description: Date when the sale of the home took place
# >
# > Data type: obj
#
# **price**:
# > Description: Selling price of home
# >
# > Data type: obj

# %% [markdown]
# ### Step 5: Create Copies of DataFrames to Start Cleaning Process

# %%
###### TO DO ######

# create a copy of house_data
house_df = house_data_df
# create a copy of sales_data
sale_df = house_sales_df

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was copied succussfully
house_df.head(5)
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was copied succussfully
sale_df.head(5)
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ## Part 2: Assess Data and Create Data Cleaning Plan

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Etc.

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.head(3)
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
#
#   Waterfront?       View House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor    OK Condition    7.0      1180.0              0
# 1          No  Very Poor    OK Condition    7.0      2170.0            400
# 2          No  Very Poor    OK Condition    6.0       770.0              0
#
#    Year Built  Year Renovated  Zipcode      Lat     Long  SQFT living 15  \
# 0      1955.0             NaN  98178.0  47.5112 -122.257            1340
# 1      1951.0          1991.0  98125.0  47.7210 -122.319            1690
# 2      1933.0             NaN  98028.0  47.7379 -122.233            2720
#
#    SQFT lot 15
# 0         5650
# 1         7639
# ...

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
sale_df.head(3)
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00

# %%
sale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# ### Step 2: Validate Data Types

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
sale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# Q: Do any of the data types in the dataframe need to be changed?

# %% [markdown]
# A: #### 1. Need to change dataypes where === object to correct assignment
# #### 2. df["column name"] = df.column_name.astype("correct_data_type") ("int") ("float")
#     ##### 2a. sale_df (id - obj) (price - need to remove money sign - to int) (date - to datetime value)
#     ##### 2b. house_df (id - obj) (zipcode - obj)

# %% [markdown]
# ### Step 3: Detect Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
sale_df.isna().sum(axis = 0)
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         4
# dtype: int64

# %%
house_df.isna().sum(axis = 0)
# Out:
# Unnamed: 0           0
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT living          0
# SQFT lot             2
# Floors               0
# Waterfront?          8
# View                 2
# House Condition      6
# Grade                2
# SQFT above           1
# SQFT basement        0
# Year Built           1
# Year Renovated     337
# Zipcode              3
# Lat                  1
# Long                 1
# SQFT living 15       0
# SQFT lot 15          0
# dtype: int64

# %%
house_df.isna().any(axis = 1)
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 21608    False
# 21609    False
# 21610     True
# 21611    False
# 21612     True
# Length: 21613, dtype: bool

# %%
house_df[house_df.isna().any(axis = 1)]
# Out:
#        Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  \
# 0               0  7129300520         3       1.00         1180    5650.0
# 2               2  5631500400         2       1.00          770   10000.0
# 3               3  2487200875         4       3.00         1960    5000.0
# 4               4  1954400510         3       2.00         1680    8080.0
# 5               5  7237550310         4       4.50         5420  101930.0
# ...           ...         ...       ...        ...          ...       ...
# 21238       21238  7299601870         3       2.50         1572    4000.0
# 21240       21240  7174800094         1       1.50         1030    5923.0
# 21247       21247  7169500020         2       2.25         1470    1101.0
# 21610       21610  1523300141         2       0.75         1020    1350.0
# 21612       21612  1523300157         2       0.75         1020    1076.0
#
#        Floors Waterfront?       View  House Condition  Grade  SQFT above  \
# ...

# %%
sale_df[sale_df.isna().any(axis = 1)]
# Out:
#        Unnamed: 0          Id             DATE Price
# 5126         5126  5412101150  20150203T000000   NaN
# 19847       19847  9211010260  20140617T000000   NaN
# 21521       21521  7430500110  20141209T000000   NaN
# 21578       21578   567000385  20140623T000000   NaN

# %%
sale_df.duplicated().describe()
# Out:
# count     21613
# unique        1
# top       False
# freq      21613
# dtype: object

# %%
sale_df.duplicated().sum()
# Out:
# 0

# %%
house_df.duplicated().sum()
# Out:
# 0

# %%
sale_df.Id.describe()
# Out:
# count    2.161300e+04
# mean     4.580302e+09
# std      2.876566e+09
# min      1.000102e+06
# 25%      2.123049e+09
# 50%      3.904930e+09
# 75%      7.308900e+09
# max      9.900000e+09
# Name: Id, dtype: float64

# %% [markdown]
# Q: Which variables/columns have missing values?

# %% [markdown]
# A: In sale_df the Price field is missing 4 values
#
#    In house_df bathrooms (2), sqft lot (2), waterfront (8), view (2), house condition (6), grade (2), sqft above (1),
#    year built (1), renovated (337), zipcode (3), lat (1), lon (1) are all missing () values

# %% [markdown]
# ### Step 4: Detect Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.describe()
# Out:
#         Unnamed: 0            ID      Bedrooms     Bathrooms   SQFT living  \
# count  21613.00000  2.161300e+04  21613.000000  21611.000000  21613.000000
# mean   10806.00000  4.580302e+09      3.372091      2.115173   2079.899736
# std     6239.28002  2.876566e+09      0.947533      0.772019    918.440897
# min        0.00000  1.000102e+06      0.000000      0.000000    290.000000
# 25%     5403.00000  2.123049e+09      3.000000      1.750000   1427.000000
# 50%    10806.00000  3.904930e+09      3.000000      2.250000   1910.000000
# 75%    16209.00000  7.308900e+09      4.000000      2.500000   2550.000000
# max    21612.00000  9.900000e+09     33.000000     10.000000  13540.000000
#
#            SQFT lot        Floors         Grade    SQFT above  SQFT basement  \
# count  2.161100e+04  21613.000000  21611.000000  21612.000000   21613.000000
# mean   1.510388e+04      1.494309      7.656795   1788.861281     291.509045
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(data=house_df['Bedrooms'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=house_df['Bathrooms'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=house_df['SQFT living'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=house_df['SQFT lot'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=house_df['Floors'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=house_df['Grade'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=house_df['SQFT above'])
# Out:
# <Axes: >

# %%
sns.boxplot(x = house_df['SQFT above'])
# Out:
# <Axes: xlabel='SQFT above'>

# %%
sns.boxplot(x = house_df['SQFT basement'])
# Out:
# <Axes: xlabel='SQFT basement'>

# %%
sns.boxplot(x = house_df['Year Built'])
# Out:
# <Axes: xlabel='Year Built'>

# %%
sns.boxplot(x = house_df['Year Renovated'])
# Out:
# <Axes: xlabel='Year Renovated'>

# %%
filtered_data = house_df.dropna(subset=["Year Renovated"]).copy()

# %%
sns.boxplot(x = filtered_data["Year Renovated"])
# Out:
# <Axes: xlabel='Year Renovated'>

# %%
sns.boxplot(x = filtered_data["SQFT living"])
# Out:
# <Axes: xlabel='SQFT living'>

# %%
sns.boxplot(x = filtered_data["SQFT lot"])
# Out:
# <Axes: xlabel='SQFT lot'>

# %%
house_df["SQFT lot"].min()
# Out:
# 520.0

# %%
sns.boxplot(x = filtered_data["SQFT living"])
# Out:
# <Axes: xlabel='SQFT living'>

# %%
house_df["SQFT lot"].head(100)
# Out:
# 0      5650.0
# 1      7242.0
# 2     10000.0
# 3      5000.0
# 4      8080.0
#        ...
# 95    10250.0
# 96    15681.0
# 97     6400.0
# 98    41800.0
# 99    36847.0
# Name: SQFT lot, Length: 100, dtype: float64

# %%
sns.boxplot(x = filtered_data["Year Renovated"])
# Out:
# <Axes: xlabel='Year Renovated'>

# %%
sns.boxplot(x = filtered_data["SQFT lot"])
# Out:
# <Axes: xlabel='SQFT lot'>

# %%
house_df["Year Renovated"]
# Out:
# 0           NaN
# 1        1991.0
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 21608       0.0
# 21609       0.0
# 21610       0.0
# 21611       0.0
# 21612       0.0
# Name: Year Renovated, Length: 21613, dtype: float64

# %% [markdown]
# Q: Which variables/columns have outliers?

# %% [markdown]
# A: ##### TO DO #####
#
# A lot of the houses have outliers including Sqft living, sqft lot, bedrooms, bathrooms... However houses come in all shapes and sizes, I did some research and it looks like all of the outliers in these column categories are within reason for house size, bedroom number etc.
#
# The outliers that proved to be harmful to the data set would be in the categories Year built and renovated... Year built shows an outlier in the 1000s which is likely a data entry error.. and Year renovated is showing a mean of 85 which likely means there is a lot of inaccurate data within the column.

# %% [markdown]
# ### Step 5: Write Data Cleaning Plan

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# # Data Cleaning Plan:
#
# ## Step 1: Check Column Names, Casing, Spelling, Etc.
#
# #### 1. Convert all columns to lower case for both dfs - df.columns = df.columns.lower()
# #### 2. Remove spaces in columns for both dfs - df.columns = df.columns.replace( " ", "")
# #### 3. Drop unamed columns in both dfs  df.drop(columns = "unnamed:0")
# #### 4. Rename any columns that need updates for better read/understanding
# #### 5. If time create a python function to convert column names to camelcase or snakecase
#
# ## Step 2: Validate Data Types
#
# #### 1. Need to change dataypes where === object to correct assignment
# #### 2. df["column name"] = df.column_name.astype("correct_data_type") ("int") ("float")
#     ##### 2a. sale_df (id - obj) (price - need to remove money sign - to int) (date - to datetime value)
#     ##### 2b. house_df (id - obj) (zipcode - obj)
#
#
# ## Step 3: Detect Missing Values
#
# #### 1. Need to remove rows for with few missing values (bathrooms (2), sqft lot (2), waterfront (8), view (2), house condition (6), grade (2), sqft above (1), year built (1), zipcode (3), lat (1), lon (1)) Only losing 29 of 21,000 + rows (small amount of data being removed)
# #### 2. Keep missing values for year renovated (these are houses that have not been renovated so leaving NaN makes sense)
# #### 3. Add mean of price for 4 missing values (could also drop potentially)
#
# ## Step 4: Detect Outliers
#
# #### 1. A lot of the houses have outliers including Sqft living, sqft lot, bedrooms, bathrooms... However houses come in all shapes and sizes, I did some research and it looks like all of the outliers in these column categories are within reason for house size, bedroom number etc.
#
# #### 2. The outliers that proved to be harmful to the data set would be in the categories Year built and renovated... Year built shows an outlier in the 1000s which is likely a data entry error.. and Year renovated is showing a mean of 85 which likely means there is a lot of inaccurate data within the column.

# %% [markdown]
# ## Part 3: Execute Data Cleaning Plan Using DEFINE / CLEAN / TEST Approach

# %% [markdown]
# ### Step 1: Understand DEFINE / CLEAN / TEST Approach

# %% [markdown]
# Refer to project instructions for an explanation of this step. You can copy and past the template in the cell below to use in each step of Part 3 as you are treating the issues you found in the data.

# %%
### DEFINE ###



### CLEAN ### 


### TEST ###

# %% [markdown]
# ### Step 2: Treat Names / Casing / Spelling Issues

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Bedrooms', 'Bathrooms', 'SQFT living', 'SQFT lot',
#        'Floors', 'Waterfront?', 'View', 'House Condition', 'Grade',
#        'SQFT above', 'SQFT basement', 'Year Built', 'Year Renovated',
#        'Zipcode', 'Lat', 'Long', 'SQFT living 15', 'SQFT lot 15'],
#       dtype='object')

# %%
### DEFINE ###

# Drop "Unamed: 0" column from DataFrame

### CLEAN ### 

house_df.drop(columns=['Unnamed: 0'], inplace=True)


### TEST ###

house_df.head() # Unamed column should not appear
# Out:
#            ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors Waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         View  House Condition  Grade  SQFT above  SQFT basement  Year Built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###

# Drop "Unamed: 0" column from DataFrame

### CLEAN ### 

sale_df.drop(columns=['Unnamed: 0'], inplace=True)


### TEST ###

sale_df.head() # Unamed column should not appear
# Out:
#            Id             DATE        Price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
### DEFINE ###

# Make column names lowercase in sales dataframe

### CLEAN ### 

sale_df.columns = sale_df.columns.str.lower()


### TEST ###

sale_df.head() # Columns should now be lowercase
# Out:
#            id             date        price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
### DEFINE ###

# Make column names lowercase in house dataframe

### CLEAN ### 

house_df.columns = house_df.columns.str.lower()


### TEST ###

house_df.head() # Columns should now be lowercase
# Out:
#            id  bedrooms  bathrooms  sqft living  sqft lot  floors waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         view  house condition  grade  sqft above  sqft basement  year built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
house_df.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft living', 'sqft lot', 'floors',
#        'waterfront?', 'view', 'house condition', 'grade', 'sqft above',
#        'sqft basement', 'year built', 'year renovated', 'zipcode', 'lat',
#        'long', 'sqft living 15', 'sqft lot 15'],
#       dtype='object')

# %%
### DEFINE ###

# Add snake_case to all column names in house data frame 

### CLEAN ### 

house_df.columns = ['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
       'waterfront?', 'view', 'house_condition', 'grade', 'sqft_above',
       'sqft_basement', 'year_built', 'year_renovated', 'zipcode', 'lat',
       'long', 'sqft_living_15', 'sqft_lot_15']


### TEST ###

house_df.head() # Columns should now be snake case
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         view  house_condition  grade  sqft_above  sqft_basement  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###

# Remove dollar sign from price column

### CLEAN ### 

sale_df["price"] = sale_df["price"].str.replace("$", "")


### TEST ###

sale_df.head() # Price should no longer have $ sign
# Out:
# /var/folders/5n/drthnqmd4bx8v0w3q9zm841m0000gn/T/ipykernel_44432/3361106757.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sale_df["price"] = sale_df["price"].str.replace("$", "")
#            id             date       price
# 0  7129300520  20141013T000000  221,900.00
# 1  6414100192  20141209T000000  538,000.00
# 2  5631500400  20150225T000000  180,000.00
# 3  2487200875  20141209T000000  604,000.00
# 4  1954400510  20150218T000000  510,000.00

# %%
### DEFINE ###

# Remove , sign from price column

### CLEAN ### 

sale_df["price"] = sale_df["price"].str.replace(",", "")


### TEST ###

sale_df.head() # Price should no longer have , sign
# Out:
#            id             date      price
# 0  7129300520  20141013T000000  221900.00
# 1  6414100192  20141209T000000  538000.00
# 2  5631500400  20150225T000000  180000.00
# 3  2487200875  20141209T000000  604000.00
# 4  1954400510  20150218T000000  510000.00

# %%
### DEFINE ###

# Save price in sale data frame as an float with only 2 decimal places

### CLEAN ### 

sale_df.price = sale_df.price.astype(float)


### TEST ###

sale_df.info() # price column will now show as a float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21613 non-null  int64
#  1   date    21613 non-null  object
#  2   price   21609 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 506.7+ KB

# %%
### DEFINE ###

# remove ? from waterfront column so that doesn't interfere with python syntax

### CLEAN ### 

house_df.rename(columns={'waterfront?': 'waterfront'}, inplace=True)


### TEST ###

house_df.info() # should remove ? from waterfront column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  int64
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21610 non-null  float64
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###

# Save id as a string in sale dataframe

### CLEAN ### 

sale_df.id = sale_df.id.astype(str)

### TEST ###

sale_df.info() # id column will now show as an object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21613 non-null  object
#  1   date    21613 non-null  object
#  2   price   21609 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 506.7+ KB

# %%
### DEFINE ###

# Save date as a date type in sale dataframe

### CLEAN ### 

sale_df['date'] = pd.to_datetime(sale_df['date'], format='%Y%m%dT%H%M%S')

### TEST ###

sale_df.info() # date column will now show as a date type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21613 non-null  object
#  1   date    21613 non-null  datetime64[ns]
#  2   price   21609 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 506.7+ KB

# %%
sale_df
# Out:
#                id       date     price
# 0      7129300520 2014-10-13  221900.0
# 1      6414100192 2014-12-09  538000.0
# 2      5631500400 2015-02-25  180000.0
# 3      2487200875 2014-12-09  604000.0
# 4      1954400510 2015-02-18  510000.0
# ...           ...        ...       ...
# 21608   263000018 2014-05-21  360000.0
# 21609  6600060120 2015-02-23  400000.0
# 21610  1523300141 2014-06-23  402101.0
# 21611   291310100 2015-01-16  400000.0
# 21612  1523300157 2014-10-15  325000.0
#
# [21613 rows x 3 columns]

# %%
sale_df.head()
# Out:
#            id       date     price
# 0  7129300520 2014-10-13  221900.0
# 1  6414100192 2014-12-09  538000.0
# 2  5631500400 2015-02-25  180000.0
# 3  2487200875 2014-12-09  604000.0
# 4  1954400510 2015-02-18  510000.0

# %%
### DEFINE ###

# Save id as a str in house data frame

### CLEAN ### 

house_df.id = house_df.id.astype(str)

### TEST ###

house_df.info() # house id column will now show as an obj
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21610 non-null  float64
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###

# Save zipcode as a str in house data frame

### CLEAN ### 

house_df.zipcode = house_df.zipcode.astype(str)

### TEST ###

house_df.info() # house zipcode column will now show as an obj
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21613 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###

# Save year_built as a int in house data frame (don't need decimals for a year)

### CLEAN ### 

house_df.year_built = house_df.year_built.astype("Int64")

### TEST ###

house_df.info() # house year_built column will now show as an int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  Int64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21613 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %%
house_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180    5650.0     1.0
# 1      6414100192         3       2.25         2570    7242.0     2.0
# 2      5631500400         2       1.00          770   10000.0     1.0
# 3      2487200875         4       3.00         1960    5000.0     1.0
# 4      1954400510         3       2.00         1680    8080.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530    1131.0     3.0
# 21609  6600060120         4       2.50         2310    5813.0     2.0
# 21610  1523300141         2       0.75         1020    1350.0     2.0
# 21611   291310100         3       2.50         1600    2388.0     2.0
# 21612  1523300157         2       0.75         1020    1076.0     2.0
#
#       waterfront       view  house_condition  grade  sqft_above  \
# ...

# %%
### DEFINE ###

# Save year_renovated as a int in house data frame (don't need decimals for a year)

### CLEAN ### 

house_df.year_renovated = house_df.year_renovated.astype("Int64")

### TEST ###

house_df.info() # house year_renovated column will now show as an int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  Int64
#  13  year_renovated   21276 non-null  Int64
#  14  zipcode          21613 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %% [markdown]
# ### Step 3: Treat Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

## Step 3: Detect Missing Values

#### 1. Need to remove rows for with few missing values (bathrooms (2), sqft lot (2), waterfront (8), view (2), house condition (6), grade (2), sqft above (1), year built (1), zipcode (3), lat (1), lon (1)) Only losing 29 of 21,000 + rows (small amount of data being removed)
#### 2. Keep missing values for year renovated (these are houses that have not been renovated so leaving NaN makes sense)
#### 3. Add mean of price for 4 missing values (could also drop potentially)

## Step 4: Detect Outliers

#### 1. A lot of the houses have outliers including Sqft living, sqft lot, bedrooms, bathrooms... However houses come in all shapes and sizes, I did some research and it looks like all of the outliers in these column categories are within reason for house size, bedroom number etc. 

#### 2. The outliers that proved to be harmful to the data set would be in the categories Year built and renovated... Year built shows an outlier in the 1000s which is likely a data entry error.. and Year renovated is showing a mean of 85 which likely means there is a lot of inaccurate data within the column.

# %%
### DEFINE ###

# treating the 4 price rows which do not carry a value and place the mean price in them them from sale data frame

### CLEAN ### 

sale_df.price = sale_df.price.fillna(sale_df.price.mean())

### TEST ###

sale_df.info() # count should go from 21609 ti 21613 in price column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21613 non-null  object
#  1   date    21613 non-null  datetime64[ns]
#  2   price   21613 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 506.7+ KB

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  Int64
#  13  year_renovated   21276 non-null  Int64
#  14  zipcode          21613 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###

# treating the 8 rows which do not carry a value and placing the word "unsure" in columns

### CLEAN ### 

house_df.waterfront = house_df.waterfront.fillna("unsure")

### TEST ###

house_df.waterfront.describe() # count should go from 21605 to 21613 in waterfront column
# Out:
# count     21613
# unique        3
# top          No
# freq      21442
# Name: waterfront, dtype: object

# %%
new_data_df = house_df.loc[house_df['waterfront'] == 'unsure']

new_data_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 19848  4100500070         5        4.5         4590   14685.0     2.0
# 19870   710600160         4        3.5         2650    3474.0     2.0
# 19944  2423069039         3        2.5         2500   51836.0     1.0
# 19993  6371000148         2        1.5         1130    1340.0     2.0
# 20029  7228500037         2        1.5         1190    1361.0     2.0
# 20077  1070000110         4        2.5         2830    5932.0     2.0
# 20143  1563102965         4        3.5         3130    5000.0     3.0
# 20197  9206500250         4        4.0         3770    8899.0     2.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 19848     unsure  Very Poor    OK Condition   10.0      4590.0              0
# 19870     unsure  Very Poor    OK Condition    8.0      2230.0            420
# 19944     unsure  Very Poor    OK Condition    9.0      1510.0            990
# ...

# %%
house_df.bathrooms.describe()
# Out:
# count    21611.000000
# mean         2.115173
# std          0.772019
# min          0.000000
# 25%          1.750000
# 50%          2.250000
# 75%          2.500000
# max         10.000000
# Name: bathrooms, dtype: float64

# %%
### DEFINE ###

# treating the rows values which do not carry a bathroom value and placing the mean of bathroom column (2.11) in null columns 
# from house data frame

### CLEAN ### 

house_df.bathrooms = house_df.bathrooms.fillna(house_df.bathrooms.mean())

### TEST ###

house_df.bathrooms.info() # count should go from 21611 to 21613 in bathrooms column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: bathrooms
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  float64
# dtypes: float64(1)
# memory usage: 169.0 KB

# %%
### DEFINE ###

# treating the 2 view rows which do not carry a value and place the string "unsure" in those rows

### CLEAN ### 

house_df.view = house_df.view.fillna("unsure")

### TEST ###

house_df.view.info() # count should go from 21611 ti 21613 in view column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: view
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  object
# dtypes: object(1)
# memory usage: 169.0+ KB

# %%
house_df.view.describe()
# Out:
# count         21613
# unique            6
# top       Very Poor
# freq          19487
# Name: view, dtype: object

# %%
house_df.sqft_lot.describe()
# Out:
# count    2.161100e+04
# mean     1.510388e+04
# std      4.141929e+04
# min      5.200000e+02
# 25%      5.040000e+03
# 50%      7.618000e+03
# 75%      1.068750e+04
# max      1.651359e+06
# Name: sqft_lot, dtype: float64

# %%
### DEFINE ###

# treating the 2 rows which do not carry a sqft_lot and placing the mean of sqft_lot columns(15,000) in null columns from house data frame

### CLEAN ### 

house_df.sqft_lot = house_df.sqft_lot.fillna(house_df.sqft_lot.mean())

### TEST ###

house_df.sqft_lot.info() # count should go from 21611 to 21613 in sqft_lot column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: sqft_lot
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  float64
# dtypes: float64(1)
# memory usage: 169.0 KB

# %%
### DEFINE ###

# treating the 6 house_condition rows which do not carry a value and place the string "unsure" in those rows

### CLEAN ### 

house_df.house_condition = house_df.house_condition.fillna("unsure")

### TEST ###

house_df.house_condition.info() # count should go from 21607 to 21613 in houde_condition column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: house_condition
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  object
# dtypes: object(1)
# memory usage: 169.0+ KB

# %%
house_df.grade.describe()
# Out:
# count    21611.000000
# mean         7.656795
# std          1.175475
# min          1.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         13.000000
# Name: grade, dtype: float64

# %%
### DEFINE ###

# treating the 2 values which do not carry a grade value and placing the mean of grade(7.6) in null columns from house data frame

### CLEAN ### 

house_df.grade = house_df.grade.fillna(house_df.grade.mean())

### TEST ###

house_df.grade.info() # count should go from 21611 to 21613 in grade column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: grade
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  float64
# dtypes: float64(1)
# memory usage: 169.0 KB

# %%
house_df.sqft_above.describe()
# Out:
# count    21612.000000
# mean      1788.861281
# std        831.369379
# min        290.000000
# 25%       1190.000000
# 50%       1560.000000
# 75%       2210.000000
# max      12542.000000
# Name: sqft_above, dtype: float64

# %%
### DEFINE ###

# treating the 1 value which do not carry a sqft_above and placing the mean of sqft_above column(1,788) in null columns from house data frame

### CLEAN ### 

house_df.sqft_above = house_df.sqft_above.fillna(house_df.sqft_above.mean())

### TEST ###

house_df.sqft_above.info() # count should go from 21611 to 21613 in price column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: sqft_above
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  float64
# dtypes: float64(1)
# memory usage: 169.0 KB

# %%
house_df.year_built.describe()
# Out:
# count        21612.0
# mean     1970.958079
# std        30.108306
# min           1000.0
# 25%           1951.0
# 50%           1975.0
# 75%           1997.0
# max           2050.0
# Name: year_built, dtype: Float64

# %%
### DEFINE ###

# treating the 1 value which do not carry a year_built and placing the mean of year_built column(1971) in null columns from house data frame

### CLEAN ### 

house_df.year_built = house_df.year_built.fillna(1971)

### TEST ###

house_df.year_built.info() # count should go from 21612 to 21613 in year_built column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: year_built
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  Int64
# dtypes: Int64(1)
# memory usage: 190.1 KB

# %%
house_df.loc[house_df['long'].isnull()]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 17848  3824100286         3       2.25         2440    8378.0     1.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 17848         No  Very Poor    OK Condition    7.0      1480.0            960
#
#        year_built  year_renovated  zipcode  lat  long  sqft_living_15  \
# 17848        1962               0  98028.0  NaN   NaN            2510
#
#        sqft_lot_15
# 17848         9602

# %%
sale_df.loc[sale_df['id'] == '3824100286']
# Out:
#                id       date     price
# 17848  3824100286 2015-03-19  565000.0

# %%
### DEFINE ###

# treating the 1 value which does not carry a long/lat value and dropping from the house data frame
### CLEAN ### 

house_df = house_df.drop(house_df[house_df['id'] == '3824100286'].index)

### TEST ###

house_df.info() # count should go from 21613 to 21612 for data frame no NaN values in Long or Lat Columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21612 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21612 non-null  object
#  1   bedrooms         21612 non-null  int64
#  2   bathrooms        21612 non-null  float64
#  3   sqft_living      21612 non-null  int64
#  4   sqft_lot         21612 non-null  float64
#  5   floors           21612 non-null  float64
#  6   waterfront       21612 non-null  object
#  7   view             21612 non-null  object
#  8   house_condition  21612 non-null  object
#  9   grade            21612 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21612 non-null  int64
#  12  year_built       21612 non-null  Int64
#  13  year_renovated   21275 non-null  Int64
#  14  zipcode          21612 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###

# removing row with matching id value in the sale data frame that did not have a Long or Lat in the House data frame

### CLEAN ### 

sale_df = sale_df.drop(sale_df[sale_df['id'] == '3824100286'].index)

### TEST ###

sale_df.info() # count should go from 21613 to 21612 for data frame no NaN values in Long or Lat Columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21612 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21612 non-null  object
#  1   date    21612 non-null  datetime64[ns]
#  2   price   21612 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 675.4+ KB

# %%
house_df.year_renovated
# Out:
# 0        <NA>
# 1        1991
# 2        <NA>
# 3        <NA>
# 4        <NA>
#          ...
# 21608       0
# 21609       0
# 21610       0
# 21611       0
# 21612       0
# Name: year_renovated, Length: 21612, dtype: Int64

# %%
house_df.head(5)
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house_condition  grade  sqft_above  sqft_basement  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0        1955
# 1  Very Poor     OK Condition    7.0      2170.0            400        1951
# 2  Very Poor     OK Condition    6.0       770.0              0        1933
# 3  Very Poor  Great Condition    7.0      1050.0            910        1965
# 4  Very Poor     OK Condition    8.0      1680.0              0        1987
#
# ...

# %%
house_df.loc[house_df["year_renovated"] == 0].count()
# Out:
# id                 20362
# bedrooms           20362
# bathrooms          20362
# sqft_living        20362
# sqft_lot           20362
# floors             20362
# waterfront         20362
# view               20362
# house_condition    20362
# grade              20362
# sqft_above         20362
# sqft_basement      20362
# year_built         20362
# year_renovated     20362
# zipcode            20362
# lat                20362
# long               20362
# sqft_living_15     20362
# sqft_lot_15        20362
# dtype: int64

# %%
house_df.loc[house_df["year_renovated"].isnull()].sum()
# Out:
# id                 7129300520563150040024872008751954400510723755...
# bedrooms                                                        1152
# bathrooms                                                 689.230346
# sqft_living                                                   688719
# sqft_lot                                                   4732044.0
# floors                                                         476.5
# waterfront         NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# view               Very PoorVery PoorVery PoorVery PoorVery PoorV...
# house_condition    OK ConditionOK ConditionGreat ConditionOK Cond...
# grade                                                         2561.0
# sqft_above                                                  573216.0
# sqft_basement                                                 115503
# year_built                                                    663115
# year_renovated                                                     0
# ...

# %%
missing_count = house_df['year_renovated'].isna().sum()
print(missing_count)
# Out:
# 337

# %%
zero_count = house_df.loc[house_df["year_renovated"] == 0]
zero_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20362 entries, 326 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               20362 non-null  object
#  1   bedrooms         20362 non-null  int64
#  2   bathrooms        20362 non-null  float64
#  3   sqft_living      20362 non-null  int64
#  4   sqft_lot         20362 non-null  float64
#  5   floors           20362 non-null  float64
#  6   waterfront       20362 non-null  object
#  7   view             20362 non-null  object
#  8   house_condition  20362 non-null  object
#  9   grade            20362 non-null  float64
#  10  sqft_above       20362 non-null  float64
#  11  sqft_basement    20362 non-null  int64
#  12  year_built       20362 non-null  Int64
#  13  year_renovated   20362 non-null  Int64
#  14  zipcode          20362 non-null  object
#  15  lat              20362 non-null  float64
# ...

# %%
### DEFINE ###

# adding 0 value to year_renovated rows that have a value of null (337 rows)

### CLEAN ### 

house_df.year_renovated = house_df.year_renovated.fillna(0)

### TEST ###

house_df.year_renovated.info() # count should go from 21275 to 21612 for year_renovated column
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 21612 entries, 0 to 21612
# Series name: year_renovated
# Non-Null Count  Dtype
# --------------  -----
# 21612 non-null  Int64
# dtypes: Int64(1)
# memory usage: 358.8 KB

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21612 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21612 non-null  object
#  1   bedrooms         21612 non-null  int64
#  2   bathrooms        21612 non-null  float64
#  3   sqft_living      21612 non-null  int64
#  4   sqft_lot         21612 non-null  float64
#  5   floors           21612 non-null  float64
#  6   waterfront       21612 non-null  object
#  7   view             21612 non-null  object
#  8   house_condition  21612 non-null  object
#  9   grade            21612 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21612 non-null  int64
#  12  year_built       21612 non-null  Int64
#  13  year_renovated   21612 non-null  Int64
#  14  zipcode          21612 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %% [markdown]
# ### Step 4: Treat Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

### observed outliers: 

#### 1. A lot of the houses have outliers including Sqft living, sqft lot, bedrooms, bathrooms... 
#### However houses come in all shapes and sizes, I did some research and it looks like all of the outliers in these column categories are within reason for house size, bedroom number etc. 

#### 2. The outliers that proved to be harmful to the data set would be in the categories Year built and renovated... 
#### Year built shows an outlier in the 1000s which is likely a data entry error.. 
#### Year renovated utilized #### 1. A lot of the houses have outliers including Sqft living, sqft lot, bedrooms, bathrooms... However houses come in all shapes and sizes, I did some research and it looks like all of the outliers in these column categories are within reason for house size, bedroom number etc. 

#### 2. The outliers that proved to be harmful to the data set would be in the categories Year built and renovated... 
#### Year built shows an outlier in the 1000s which is likely a data entry error.. 
#### and Year renovated is showing a mean of 85 which likely means there is a lot of inaccurate data within the column.

# %%
from scipy.stats import zscore

# %%
zscore_house_df = house_df
zscore_sales_df = sale_df

# %%
zscore_house_df['bedrooms_zscore'] = zscore(zscore_house_df['bedrooms'])

# %%
bedrooms_zcore = zscore_house_df.query('bedrooms_zscore > 3 or bedrooms_zscore < -3')

# %%
bedrooms_zcore.head(38)
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 16     1875500060        30       2.00         1890   14040.0     2.0
# 556    5486800070         7       3.50         4640   15235.0     2.0
# 875    6306400140         0       0.00         3064    4764.0     3.5
# 1135   4024100951         7       3.00         2940    8624.0     1.0
# 1241   7227802030         7       3.00         2800    9569.0     1.0
# 1660   9126101740         8       5.00         2800    2580.0     2.0
# 3119   3918400017         0       0.00         1470     979.0     3.0
# 3467   1453602309         0       1.50         1430    1650.0     3.0
# 3721   5451100490         7       4.75         5370   10800.0     1.5
# 4024   9175600025         7       6.75         7480   41664.0     2.0
# 4035    685000115         8       6.00         4340    9415.0     2.0
# 4067   7226500100         8       3.00         2850   12714.0     1.0
# ...

# %%
house_df.bedrooms.mean()
# Out:
# 3.3721080880992043

# %%
mean_bedrooms = house_df.loc[(house_df['bedrooms'] != 0) & (house_df['bedrooms'] != 30), 'bedrooms'].mean()
mean_bedrooms
# Out:
# 3.3729048986017225

# %%
### DEFINE ###

# updating rows with value of 0 in bedrooms to mean of bedrooms column without 0 bedrooms values + 30 room value

### CLEAN ### 


house_df.loc[(house_df['bedrooms'] == 0), 'bedrooms'] = 3

### TEST ###

house_df.loc[house_df['bedrooms'] == 0] # Bedrooms with 0 rooms should return no values
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, year_renovated, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore]
# Index: []

# %%
house_df.loc[house_df['id'] == "3918400017"]
# Out:
#               id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 3119  3918400017         3        0.0         1470     979.0     3.0
#
#      waterfront     view house_condition  grade  sqft_above  sqft_basement  \
# 3119         No  Neutral    OK Condition    8.0      1470.0              0
#
#       year_built  year_renovated  zipcode      lat     long  sqft_living_15  \
# 3119        2006               0  98133.0  47.7145 -122.356            1470
#
#       sqft_lot_15  bedrooms_zscore
# 3119         1399        -3.558843

# %%
### DEFINE ###

# updating rows with value of 0 in bedrooms to mean of bedrooms column without 0 bedrooms values + 30 room value

### CLEAN ### 

house_df.loc[(house_df['bedrooms'] == 30), 'bedrooms'] = 3

### TEST ###

house_df.loc[house_df['bedrooms'] == 30] # Bedrooms with 0 rooms should return no values
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, year_renovated, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore]
# Index: []

# %%
zscore_house_df['bathroom_zscore'] = zscore(zscore_house_df['bathrooms'])

# %%
bathroom_zscore = zscore_house_df.query('bathroom_zscore > 3 or bathroom_zscore < -3')

# %%
bathroom_zscore
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420  101930.0     1.0
# 44     1432701230         3      10.00         1280    9656.0     1.0
# 270    4054500390         4       4.75         5310   57346.0     2.0
# 300    3225069065         4       5.00         4550   18641.0     1.0
# 450    4055700030         3       4.50         3970   24920.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21344  8835770170         5       6.00         6880  279968.0     2.0
# 21494  2413910120         3       4.50         3850   62726.0     2.0
# 21506  2524069097         5       6.50         7270  130017.0     2.0
# 21551  1561750040         5       4.50         4350   13405.0     2.0
# 21576  9253900271         5       4.50         4850   10584.0     2.0
#
#       waterfront       view house_condition  grade  ...  sqft_basement  \
# ...

# %%
zscore_house_df.loc[zscore_house_df["bathroom_zscore"] > 10]
# Out:
#             id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 44  1432701230         3       10.0         1280    9656.0     1.0         No
#
#          view house_condition  grade  ...  sqft_basement  year_built  \
# 44  Very Poor  Good Condition    6.0  ...            360        1959
#
#     year_renovated  zipcode      lat     long  sqft_living_15  sqft_lot_15  \
# 44               0  98058.0  47.4485 -122.175            1340         8808
#
#     bedrooms_zscore  bathroom_zscore
# 44        -0.392714        10.213749
#
# [1 rows x 21 columns]

# %%
zscore_house_df['sqft_living_zscore'] = zscore(zscore_house_df['sqft_living'])

# %%
zscore_house_df['sqft_above_zscore'] = zscore(zscore_house_df['sqft_above'])

# %%
sqft_above_zscore = zscore_house_df.query('sqft_above_zscore > 3 or sqft_above_zscore < -3')

# %%
zscore_house_df.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'house_condition', 'grade', 'sqft_above',
#        'sqft_basement', 'year_built', 'year_renovated', 'zipcode', 'lat',
#        'long', 'sqft_living_15', 'sqft_lot_15', 'bedrooms_zscore',
#        'bathroom_zscore', 'sqft_living_zscore', 'sqft_lot_zscore',
#        'floors_zscore', 'grade_zscore', 'sqft_above_zscore'],
#       dtype='object')

# %%
zscore_house_df["sqft_above"].loc[zscore_house_df["sqft_above_zscore"] > 6]
# Out:
# 3914      7680.0
# 7252      8570.0
# 9254      8860.0
# 11871     7420.0
# 12777     9410.0
# 13411     7880.0
# 18302     8020.0
# 18594     7320.0
# 19858     7850.0
# 19864    12542.0
# Name: sqft_above, dtype: float64

# %%
zscore_house_df.loc[zscore_house_df["sqft_above_zscore"] > 6]
# Out:
#                id  bedrooms  bathrooms  sqft_living      sqft_lot  floors  \
# 3914   9808700762         5       4.50        10040   37325.00000     2.0
# 7252   6762700020         6       8.00        12050   27600.00000     2.5
# 9254   9208900037         6       7.75         9890   31374.00000     2.0
# 11871  8835800350         4       3.25         7420  167869.00000     2.0
# 12777  1225069038         7       8.00        13540  307752.00000     3.0
# 13411  2426039123         5       4.75         7880   24250.00000     2.0
# 18302  6072800246         5       6.25         8020   21738.00000     2.0
# 18594  3023069166         5       4.00         7320  217800.00000     2.0
# 19858  2524069078         4       4.00         7850   15103.87784     2.0
# 19864  1776230060         4       2.50         2150    3143.00000     2.0
#
#       waterfront       view house_condition  grade  ...     long  \
# 3914         Yes    Neutral    OK Condition   11.0  ... -122.214
# ...

# %%
sqft_living_zscore = zscore_house_df.query('sqft_living_zscore > 3 or sqft_living_zscore < -3')

# %%
sqft_living_zscore
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420  101930.0     1.0
# 153    7855801670         4       3.25         5180   19850.0     2.0
# 269    7960900060         4       3.25         5050   20100.0     1.5
# 270    4054500390         4       4.75         5310   57346.0     2.0
# 419    8678500060         5       4.25         6070  171626.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21520  7237550100         4       4.00         4920   50621.0     2.0
# 21521  7430500110         5       3.50         5150   12230.0     2.0
# 21530  8964800330         4       3.75         5090   14823.0     1.0
# 21576  9253900271         5       4.50         4850   10584.0     2.0
# 21590  7430200100         4       3.50         4910    9444.0     1.5
#
#       waterfront       view house_condition  grade  ...  year_built  \
# ...

# %%
zscore_house_df.loc[zscore_house_df["sqft_living_zscore"] == 6]
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, year_renovated, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathroom_zscore, sqft_living_zscore]
# Index: []
#
# [0 rows x 22 columns]

# %%
house_df.year_built.describe()
# Out:
# count        21612.0
# mean     1970.958495
# std        30.108245
# min           1000.0
# 25%           1951.0
# 50%           1975.0
# 75%           1997.0
# max           2050.0
# Name: year_built, dtype: Float64

# %%
zscore_house_df['sqft_basement_zscore'] = zscore(zscore_house_df['sqft_basement'])

# %%
sqft_basement_zscore = zscore_house_df.query('sqft_basement > 3 or sqft_basement < -3')

# %%
sqft_basement_zscore
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 10     1736800520         3   2.115173         3560    9796.0     1.0
# 41     7766200013         4   2.250000         4220   24186.0     1.0
# 70     1525059190         5   3.250000         4770   50094.0     1.0
# 153    7855801670         4   3.250000         5180   19850.0     2.0
# 185     825059270         5   3.000000         4090   12850.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 20996  1424059154         4   3.000000         5520    8313.0     2.0
# 21050  2424059170         5   6.000000         7120   40806.0     2.0
# 21321  2387600010         4   3.500000         4680   12495.0     2.0
# 21344  8835770170         5   6.000000         6880  279968.0     2.0
# 21590  7430200100         4   3.500000         4910    9444.0     1.5
#
#       waterfront       view house_condition  grade  ...  sqft_living_15  \
# ...

# %%
zscore_house_df["sqft_basement"].loc[zscore_house_df["sqft_basement_zscore"] > 6]
# Out:
# 4411      6.120239
# 7252      7.204858
# 8092     10.232753
# 10085     6.707741
# 12777     8.673613
# 15482     7.250050
# Name: sqft_basement, dtype: float64

# %%
zscore_house_df['grade_zscore'] = zscore(zscore_house_df['grade'])

# %%
grade_zscore = zscore_house_df.query('grade_zscore > 3 or grade_zscore < -3')

# %%
grade_zscore
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 153    7855801670         4       3.25         5180   19850.0     2.0
# 350    7325600160         1       0.75          560   12120.0     1.0
# 419    8678500060         5       4.25         6070  171626.0     2.0
# 465    8658300340         1       0.75          430    5050.0     1.0
# 540     622049114         3       2.50         5403   24069.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 20441  1925059254         5       4.00         6670   16481.0     2.0
# 20471   323079101         4       3.50         6370  205603.0     2.0
# 21050  2424059170         5       6.00         7120   40806.0     2.0
# 21344  8835770170         5       6.00         6880  279968.0     2.0
# 21506  2524069097         5       6.50         7270  130017.0     2.0
#
#       waterfront       view house_condition  grade  ...      lat     long  \
# ...

# %%
zscore_house_df.loc[zscore_house_df["grade_zscore"] > 4]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 4411   2470100110         5       5.75         9200   35069.0     2.0
# 4811   9831200500         5       3.75         6810    7500.0     2.5
# 5451   7237501190         4       3.25         4890   13402.0     2.0
# 6041   1725059316         4       4.00         6330   13296.0     2.0
# 7035    853200010         5       5.50         7050   42840.0     1.0
# 7252   6762700020         6       8.00        12050   27600.0     2.5
# 7907   1068000375         6       5.00         7100   18200.0     2.5
# 9254   9208900037         6       7.75         9890   31374.0     2.0
# 10373  3303850390         5       5.50         7400   18898.0     2.0
# 13411  2426039123         5       4.75         7880   24250.0     2.0
# 13700  4139900180         4       2.50         4500   35200.0     1.0
# 14556  2303900035         5       6.25         8670   64033.0     2.0
# ...

# %%
zscore_house_df['floors_zscore'] = zscore(zscore_house_df['floors'])

# %%
floors_zscore = zscore_house_df.query('floors_zscore > 3 or floors_zscore < -3')

# %%
floors_zscore
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 875    6306400140         3       0.00         3064    4764.0     3.5
# 10077  1972202010         3       3.00         1440    1350.0     3.5
# 11594  3180100023         3       2.50         1760    1755.0     3.5
# 14885  8673400177         3       3.00         1730    1074.0     3.5
# 15424  1702900664         2       2.50         1730    1037.0     3.5
# 18477  1346300150         8       4.00         7710   11750.0     3.5
# 20308  1972200426         2       2.75         1310    1268.0     3.5
# 20772  1972200428         3       2.50         1400    1312.0     3.5
#
#       waterfront       view  house_condition  grade  ...  zipcode      lat  \
# 875           No    Neutral     OK Condition    7.0  ...  98102.0  47.6362
# 10077         No    Neutral     OK Condition    8.0  ...  98103.0  47.6525
# 11594         No  Very Poor     OK Condition    8.0  ...  98105.0  47.6688
# ...

# %%
zscore_house_df.loc[zscore_house_df["floors_zscore"] > 3]

# %%
zscore_house_df['sqft_living_15_zscore'] = zscore(zscore_house_df['sqft_living_15'])

# %%
sqft_living_15_zscore = zscore_house_df.query('sqft_living_15_zscore > 3 or sqft_living_15_zscore < -3')

# %%
sqft_living_15_zscore
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420  101930.0     1.0
# 21     2524049179         3       2.75         3050   44867.0     1.0
# 270    4054500390         4       4.75         5310   57346.0     2.0
# 300    3225069065         4       5.00         4550   18641.0     1.0
# 384     713500030         5       3.50         4800   14984.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21486    98300230         4       4.00         4620  130208.0     2.0
# 21520  7237550100         4       4.00         4920   50621.0     2.0
# 21525  2625069038         4       3.50         4300  108865.0     2.0
# 21540   715010530         5       3.50         4410   13000.0     2.0
# 21590  7430200100         4       3.50         4910    9444.0     1.5
#
#       waterfront       view house_condition  grade  ...  sqft_lot_15  \
# ...

# %%
zscore_house_df['sqft_lot_15_zscore'] = zscore(zscore_house_df['sqft_lot_15'])

# %%
sqft_lot_15_zscore = zscore_house_df.query('sqft_lot_15_zscore > 3 or sqft_lot_15_zscore < -3')

# %%
sqft_living_15_zscore
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420  101930.0     1.0
# 21     2524049179         3       2.75         3050   44867.0     1.0
# 270    4054500390         4       4.75         5310   57346.0     2.0
# 300    3225069065         4       5.00         4550   18641.0     1.0
# 384     713500030         5       3.50         4800   14984.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21486    98300230         4       4.00         4620  130208.0     2.0
# 21520  7237550100         4       4.00         4920   50621.0     2.0
# 21525  2625069038         4       3.50         4300  108865.0     2.0
# 21540   715010530         5       3.50         4410   13000.0     2.0
# 21590  7430200100         4       3.50         4910    9444.0     1.5
#
#       waterfront       view house_condition  grade  ...  sqft_lot_15  \
# ...

# %%
zscore_house_df['sqft_living_zscore'] = zscore(zscore_house_df['sqft_living'])

# %%
sqft_living_zscore = zscore_house_df.query('sqft_living_zscore > 3 or sqft_living_zscore < -3')

# %%
zscore_house_df.loc[zscore_house_df["sqft_lot_zscore"] > 10]
# Out:
#                id  bedrooms  bathrooms  sqft_living   sqft_lot  floors  \
# 1719   1020069017         4       1.00         1300  1651359.0     1.0
# 2964   2322029048         3       2.75         2830   505166.0     1.0
# 3949    722069232         4       3.25         3770   982998.0     2.0
# 4387   3523089019         4       3.50         3370   435600.0     2.0
# 4441   3626079040         2       3.00         2560   982278.0     1.0
# 4540   2522029039         3       2.00         3650   843309.0     2.0
# 5073   2322059136         3       2.50         2920   434728.0     2.0
# 6691   2624089007         2       2.50         3900   920423.0     2.0
# 7077   2724079090         4       3.25         3920   881654.0     3.0
# 7250    722039049         4       3.00         3230   438213.0     2.0
# 7294   1923039022         2       1.75         1679   577605.0     2.0
# 7647   2623069031         5       3.25         3010  1074218.0     1.5
# ...

# %%
house_df.loc[(house_df.year_built > 0) & (house_df.year_built < 2023)].describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21611.000000  21611.000000  21611.000000  2.161100e+04  21611.000000
# mean       3.372681      2.115160   2079.906205  1.510485e+04      1.494262
# std        0.926459      0.772018    918.473835  4.141915e+04      0.539906
# min        1.000000      0.000000    290.000000  5.200000e+02      1.000000
# 25%        3.000000      1.750000   1426.000000  5.040000e+03      1.000000
# 50%        3.000000      2.250000   1910.000000  7.620000e+03      1.500000
# 75%        4.000000      2.500000   2550.000000  1.069200e+04      2.000000
# max       33.000000     10.000000  13540.000000  1.651359e+06      3.500000
#
#               grade    sqft_above  sqft_basement   year_built  year_renovated  \
# count  21611.000000  21611.000000   21611.000000      21611.0         21611.0
# mean       7.656810   1788.885237     291.491601  1970.954838       84.317801
# ...

# %%
house_df.loc[house_df.year_built > 2023]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 21270  1773100541         3       2.25         1580     920.0     3.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 21270         No  Very Poor    OK Condition    8.0      1580.0              0
#
#        year_built  year_renovated  zipcode      lat     long  sqft_living_15  \
# 21270        2050               0  98106.0  47.5578 -122.363            1250
#
#        sqft_lot_15  bedrooms_zscore
# 21270         1150        -0.392714

# %%
house_df.loc[house_df.year_built < 1800]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20981  3746700120         3        3.5         3940   11632.0     2.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 20981         No  Very Poor    OK Condition   10.0      3940.0              0
#
#        year_built  year_renovated  zipcode     lat     long  sqft_living_15  \
# 20981        1000               0  98166.0  47.438 -122.344            2015
#
#        sqft_lot_15  bedrooms_zscore
# 20981        11632        -0.392714

# %%
### DEFINE ###

### adjusting row that has a year_built value of 1000 to the mean of the year_built column without outlier values (1971)

### CLEAN ### 

house_df.loc[house_df.year_built == 1000, 'year_built'] = 1971

### TEST ###

house_df.loc[house_df.year_built == 1000] # should show no rows with this value
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, year_renovated, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore]
# Index: []

# %%
### DEFINE ###

### adjusting row that has a year_built value of 2050 to the mean of the year_built column without outlier values (1971)

### CLEAN ### 

house_df.loc[house_df.year_built == 2050, 'year_built'] = 1971

### TEST ###

house_df.loc[house_df.year_built == 2050] # should show no rows with this value
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, year_renovated, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore]
# Index: []

# %% [markdown]
# ### Step 5: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Converting Values
#
# ###### Not much to justify here but performed the following:
# ###### 1. converted column names to more python friendly syntax (lower case, snake_case, removed ? from waterfront column)
# ###### 2. removed the unamed: id column because didn't bring any value to either of the dataframes (we could use id for merging later)
# ###### 3. removed the dollar sign and , from the price values in sale_df so that it could later be converted to integer
# ###### 4. converted id columns, zipcode columns to str datatype, price to an integer datatype and date to a date time datatype (this makes analyzing data possible. For example after converting price to an integer it could then be used in an equation)
#
# ### Step 2: Detect Missing Values
#
# ###### 1. Converted following missing values to the mean of entire column (bathrooms (2), sqft lot (2), grade (2), sqft above (1), year built (1))
#         Justification -> by placing in the mean we retain accurate values all other columns in 10 rows
# ###### 2. Converted following missing values to the str "unsure" (waterfront (8), view (2), house condition (6), zipcode (3))
#         Justification -> by placing unsure we retain accurate values all other columns in 10 rows and can filter out unsure values if we are analyzing data of a singular row
# ###### 3. Dropped the one row that did not have a latitude or longitude value + removed row with matching id value in sale_df
#         Justification -> only one row so not losing lots of data in 21,000+ df. plus no way to accurately fill information in with a mean or mode bc lat/long are pin point location
#
# ### Step 3: Detect Outliers
#
# ###### 1. Several houses had outliers in Sqft living, sqft lot, bedrooms, bathrooms columns -> did not adjust to mean for these rows
#     1a. Bedrooms -> adjusted houses with 0 bedrooms to mean (data error) house with 30 bedrooms adjusted to mean bc it had 2 bathrooms so must have been a data entry error... Rest that had a zscore above 3 all seemed to be legitimate houses and would not affect the data sample
#     2a Bathrooms -> Bathrooms had 188 outside of zcore 3... However all were reasonable and could be a legitmate amount of bathrooms for given house. Thus, I did not adjust any of these rows
#     3a Sqft living -> Similiar to bathrooms, all sqft_living houses with zscore above 3 were all reasonablly sized will not adjust any of these rows
#     4a Sqft lot ->  Similiar to bathrooms, all sqft_lots houses with zscore above 3 were all reasonablly sized will not adjust any of these rows (biggest acerage was 37 which is reasonable)
#     5a Floors -> only flag on the zscore are houses with 3.5 floors which is viable with basement, ground floor, second floor, and attic. No change to those rows
#     6a Grade -> grade does trigger many above 3 on a zscore, but the highest grade is a 13 which is reasonable (will not drop)
#     7a sqft_above/sqft_basement -> none that are unrealistic outliers will not change any values/drop these rows
#     8a sqft_lot_15/sqft_living_15 -> none that are unrealistic outliers will not change any values/drop these rows
#
#          Justification -> Because houses come in all shapes and sizes, most of the outliers in these column categories are within reason for house size, bedroom number etc. Ideally we would remove some of these outliers and see how much it affects data in following steps. But with such a large dataset and such a low percentage of outliers, removing outliers won't have a huge impact on overall data.
#
# ###### 2. The outliers that proved to be harmful to the data set would be in the categories Year built and renovated -> adjusted values in these rows
#      2a. Year built shows an outlier in the 1000s and 2050 which is likely a data entry error.. Switched to the mean of the column year built when these two rows are removed which was (1971)
#      2b. Year renovated utilized both 0 and NaN for rows that did not hold a value... Initially this looked like it there was a large amount of outliers, but this was more of a missing value error. I replaced all NaN values with 0s which will allow us to differentiate between 0 and non 0 numbers in future analysis

# %%
house_data_basement_df = pd.read_csv("house_data.csv")

# %%
house_data_basement_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Bedrooms', 'Bathrooms', 'SQFT living', 'SQFT lot',
#        'Floors', 'Waterfront?', 'View', 'House Condition', 'Grade',
#        'SQFT above', 'SQFT basement', 'Year Built', 'Year Renovated',
#        'Zipcode', 'Lat', 'Long', 'SQFT living 15', 'SQFT lot 15'],
#       dtype='object')

# %%
house_df["sqft_basement"] = house_data_basement_df['SQFT basement']

# %% [markdown]
# ## Part 4: Re-Express Categorical Variables

# %% [markdown]
# ### Step 1: Determine Which Variables Need to Be Re-Expressed

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180    5650.0     1.0
# 1      6414100192         3       2.25         2570    7242.0     2.0
# 2      5631500400         2       1.00          770   10000.0     1.0
# 3      2487200875         4       3.00         1960    5000.0     1.0
# 4      1954400510         3       2.00         1680    8080.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530    1131.0     3.0
# 21609  6600060120         4       2.50         2310    5813.0     2.0
# 21610  1523300141         2       0.75         1020    1350.0     2.0
# 21611   291310100         3       2.50         1600    2388.0     2.0
# 21612  1523300157         2       0.75         1020    1076.0     2.0
#
#       waterfront       view  house_condition  grade  sqft_above  \
# ...

# %% [markdown]
# List categorical variables which need to be re-expressed here:
#
# - waterfront
# - view
# - house_condition

# %%
house_df.house_condition.unique()
# Out:
# array(['OK Condition', 'Great Condition', 'Good Condition',
#        'Very Bad Condition', 'Bad Condition', 'unsure'], dtype=object)

# %%
count = (house_df['waterfront'] == 'Yes').sum()
count
# Out:
# 163

# %% [markdown]
# ### Step 2: Choose Method to Re-Express Variables

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to re-express each variable and why.
# - waterfront -> assign unsures to no (explain in logic below). assign yes to 1 and no to 0
# - view -> going to replace with weighted integers (1 - 5) very poor (1), poor (2), neutral (3), good (4), great (5) and a (0) for unsure
# - house_condition -> going to replace with weighted integers (1 - 5) very bad condition (1), bad condition (2), ok condition (3), good condition (4), great condition (5) and a (0) for unsure

# %% [markdown]
# ### Step 3: Perform Transformation

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
### Waterfront transformation -> changing waterfont category so that yes is now a 1 and no/unsure is 0

house_df['waterfront'] = house_df['waterfront'].replace({'Yes':1, "No":0, "unsure":0})

# %%
### TEST ###

house_df.waterfront.unique()
# Out:
# array([0, 1])

# %%
house_df.view.unique()
# Out:
# array(['Very Poor', 'Good', 'Great', 'Neutral', 'unsure', 'Poor'],
#       dtype=object)

# %%
### DEFINE ###

# performing transformation on view -> going to replace with weighted 
# integers (1 - 5) very poor (1), poor (2), neutral (3), good (4), great (5) and a (0) for unsure

### transform ### 

house_df["view"] = house_df['view'].replace({'unsure': 0, 'Very Poor':1, 'Poor':2, 'Neutral':3, 'Good':4, 'Great':5})

### TEST ###

house_df.view.unique() # should see values for number 0 - 6
# Out:
# array([1, 4, 5, 3, 0, 2])

# %%
house_df.house_condition.unique()
# Out:
# array(['OK Condition', 'Great Condition', 'Good Condition',
#        'Very Bad Condition', 'Bad Condition', 'unsure'], dtype=object)

# %%
### DEFINE ###

# performing transformation on house_condition -> going to replace with weighted integers (1 - 5) 
# very bad condition (1), bad condition (2), ok condition (3), good condition (4), great condition (5) 
# and a (0) for unsure

### transform ### 

house_df["house_condition"] = house_df['house_condition'].replace({'unsure': 0, 'Very Bad Condition':1, 'Bad Condition':2, 'OK Condition':3, 'Good Condition':4, 'Great Condition':5})

### TEST ###

house_df.house_condition.unique() # should see values for number 0 - 6
# Out:
# array([3, 5, 4, 1, 2, 0])

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21612 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21612 non-null  object
#  1   bedrooms         21612 non-null  int64
#  2   bathrooms        21612 non-null  float64
#  3   sqft_living      21612 non-null  int64
#  4   sqft_lot         21612 non-null  float64
#  5   floors           21612 non-null  float64
#  6   waterfront       21612 non-null  int64
#  7   view             21612 non-null  int64
#  8   house_condition  21612 non-null  int64
#  9   grade            21612 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21612 non-null  int64
#  12  year_built       21612 non-null  Int64
#  13  year_renovated   21612 non-null  Int64
#  14  zipcode          21612 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %% [markdown]
# ### Step 4: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ##### Justifications for re-expressions:
#
# ###### 1. waterfront -> took the boolean approach here assigning 1 to yes and 0 to no. Earlier in the project i replace all unknown values with "unsure", because there were only 8 of these values and more then 99% of the filled values were no I also assigned unsure to no.
# ###### 2. view -> with views being a ranking scale from very poor to great i decided to scale from 1 to 5 with each number be associate to a its given rank value 1 was the worst and 5 was the best. I also placed unsure variable as 0 so we wouldn't lose any data from the df and so that we could easily filter without harming the data
# ###### 3. house_condition -> with condition being a ranking scale from very bad to great i decided to scale from 1 to 5 with each number be associate to a its given rank value 1 was the worst and 5 was the best. I also placed unsure variable as 0 so we wouldn't lose any data from the df and so that we could easily filter without harming the data

# %% [markdown]
# ## Part 5: Combine Datasets into Master DataFrame

# %% [markdown]
# ### Step 1: Choose Method to Merge DataFrames into New Master DataFrame

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to merge the data and why.
#
# Using the merge pandas method because we have a like column on ID that we can combine all information on.

# %% [markdown]
# ### Step 2: Merge DataFrames

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
master_df = sale_df.merge(house_df, on = 'id')

# %%
master_df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     1  ...    7.0      1180.0              0
# 1    7242.0     2.0           0     1  ...    7.0      2170.0            400
# 2   10000.0     1.0           0     1  ...    6.0       770.0              0
# 3    5000.0     1.0           0     1  ...    7.0      1050.0            910
# 4    8080.0     1.0           0     1  ...    8.0      1680.0              0
#
#    year_built  year_renovated  zipcode      lat     long  sqft_living_15  \
# ...

# %% [markdown]
# ### Step 3: Save Master DataFrame to New .CSV

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
master_df.to_csv('master.csv', index=False)

# %% [markdown]
# ### Step 4: Push to GitHub / Share Link with Tech Lead & SME

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.

# %% [markdown]
# ### Step 5: Record Brief Code Walkthrough / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.
